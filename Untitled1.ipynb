# %% [markdown]
# <a href="https://colab.research.google.com/github/Shiva-Kumar-S-M/Placement-Training/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Flatten images
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# Normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(784,)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9197 - loss: 0.2725 - val_accuracy: 0.9576 - val_loss: 0.1418
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9657 - loss: 0.1108 - val_accuracy: 0.9650 - val_loss: 0.1127
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9766 - loss: 0.0744 - val_accuracy: 0.9688 - val_loss: 0.1062
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9823 - loss: 0.0566 - val_accuracy: 0.9689 - val_loss: 0.1005
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9855 - loss: 0.0454 - val_accuracy: 0.9742 - val_loss: 0.0888
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9890 - loss: 0.0356 - val_accuracy: 0.9729 - val_loss: 0.0989
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9898 - loss: 0.0303 - val_accuracy: 0.9740 - val_loss: 0.1006
# Epoch 8/10
# ...

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9779 - loss: 0.0955
# Test Accuracy: 0.9779000282287598

# %%
y_pred = model.predict(x_test)

pred_label = np.argmax(y_pred, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
print("Accuracy:", accuracy_score(y_test, pred_label))
# Out:
# Accuracy: 0.9779

# %%
print(classification_report(y_test, pred_label))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.98      1032
#            3       0.96      0.99      0.97      1010
#            4       0.98      0.97      0.98       982
#            5       0.97      0.97      0.97       892
#            6       0.99      0.96      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.97      0.96      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
cm = confusion_matrix(y_test, pred_label)

plt.figure(figsize=(10,8))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    linewidths=0.5,
    square=True,
    xticklabels=np.arange(10),
    yticklabels=np.arange(10)
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
